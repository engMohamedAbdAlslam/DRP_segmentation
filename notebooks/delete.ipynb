# %%
import pandas as pd
df = pd.DataFrame({'age':['1','12','2','33','44','444'],'name':['a','v','s','a','e','ds']})

# %%
df.head(6)
# Out:
#    age name
# 0    1    a
# 1   12    v
# 2    2    s
# 3   33    a
# 4   44    e
# 5  444   ds

# %%
df.iloc[0]
# Out:
# age     1
# name    a
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# age     12
# name     v
# Name: 1, dtype: object
